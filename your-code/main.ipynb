# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
# functional style

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
# object-oriented style

fig, ax = plt.subplots(1,2)

ax[0].plot(x, y)
ax[0].set_title("linear function")

ax[1].plot(x, z)
ax[1].set_title("exponential function")
# Out:
# Text(0.5, 1.0, 'exponential function')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))

ax[0].plot(x, y, linewidth = 3, alpha = 0.5, ls = "--", c = "yellow")
ax[0].set_title("linear function")

ax[1].plot(x, z, linewidth = 3, alpha = 0.5, ls = "--", c = "purple")
ax[1].set_title("exponential function")
# Out:
# Text(0.5, 1.0, 'exponential function')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
#
# **Hint**: Use `set_xscale` and `set_yscale`.

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
import math
x = np.arange(0,100)
y = x*2
z = np.exp(x)

# %%
fig, ax = plt.subplots(1,2,figsize = (10,5))

ax[0].plot(x, y, label = "y = x^2", color = "red")
ax[0].set_xlabel("x")
ax[0].set_ylabel("y")
ax[0].set_yscale("linear")

ax[1].plot(x, z, label = "y = e^x", color = "green")
ax[1].set_xlabel("x")
ax[1].set_ylabel("log y")
ax[1].set_yscale("log")

ax[0].legend()
ax[1].legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv("../../Datasets as CSV/Fitbit2.csv")

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fit = fitbit[["Steps","Months_encoded","Work_or_Weekend"]]

# %%
fit
# Out:
#      Steps  Months_encoded  Work_or_Weekend
# 0      905               5                1
# 1    18925               5                0
# 2    14228               5                0
# 3     6756               5                1
# 4      502               5                1
# ..     ...             ...              ...
# 362  18588               5                1
# 363  16382               5                1
# 364  21913               5                1
# 365  19023               5                1
# 366   9526               5                0
#
# [367 rows x 3 columns]

# %%
month = fit.groupby("Months_encoded")["Steps"].median().reset_index()
month_x = month["Months_encoded"]
month_y = month["Steps"]

# %%
week = fit.groupby("Work_or_Weekend")["Steps"].median().reset_index()
week_x = week["Work_or_Weekend"]
week_y = week["Steps"]

# %%
fig, ax = plt.subplots(1,2,figsize =(12,4))

ax[0].bar(month_x, month_y)
plt.sca(ax[0])
plt.xticks(month_x, ["Jan", "Feb", "Mar", "Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"])


ax[1].bar(week_x, week_y)
ax[1].set_ylim([9000,11000])

plt.sca(ax[1])
plt.xticks(week_x, ["Weekend", "Work"])
# Out:
# ([<matplotlib.axis.XTick at 0x1a1c17ec50>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fit2 = fitbit[["Minutes Sedentary", "Minutes Lightly Active", "Minutes Very Active","Steps"]]

# %%
fig, ax = plt.subplots(1,3,figsize =(18,4))

for i in range(0,3):
    ax[i].scatter(fit2.iloc[:,i], fit2["Steps"])
    ax[i].set_ylabel("Steps")
    ax[i].set_xlabel(fit2.columns[i])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("../../Datasets as CSV/titanic.csv")

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include="number").columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include="object").columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
y = titanic['age'].value_counts()
y
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
x = age.index
x
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
y = titanic['age'].value_counts()
x = age.index

fig5,ax5 = plt.subplots(figsize=(7,6))

ax5.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-64fed7857ae6> in <module>
#       4 fig5,ax5 = plt.subplots(figsize=(7,6))
#       5
# ----> 6 ax5.bar(x,y)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
# ...

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
a = titanic['Age']
  
# Creating histogram 
fig, ax = plt.subplots(figsize =(10, 7)) 
ax.hist(a, bins = [0,10, 20, 50]) 
  
# Show plot 
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
titanic = sns.load_dataset('titanic')
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
age = titanic["age"]

# %%
sns.set_palette('RdYlGn')
palette_alive = {"yes": "C5", "no": "C0"}

# %%
age_bins = range(0,100, 10)
x_titanic = age

# %%
fig,axs7 = plt.subplots(figsize = (14,6))

sns.distplot(x_titanic,bins=age_bins,ax=axs7)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

# your code here

gender = titanic['sex'].value_counts()
x = gender.index

# %%
fig8,ax8 = plt.subplots(figsize=(10,6))
ax8.bar(x,gender)
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here

fig9,ax9 = plt.subplots(figsize=(12,8))

sns.barplot(x = x, y = gender, ax=ax9)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
pclass = titanic['pclass'].value_counts()
x = pclass.index

fig10,ax10 = plt.subplots(figsize=(10,6))
sns.barplot(x = x, y = pclass, ax=ax10)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.catplot(data=titanic,y="age",kind="box")

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

age = titanic['age'].value_counts()
x = age.index

fig10,ax10 = plt.subplots(figsize=(20,10))
sns.barplot(x = x, y = age, ax=ax10)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
age = titanic['age']
fare = titanic['fare']

fig12,ax12 = plt.subplots(figsize=(30,5))
ax12.scatter(age,fare)

# %%
# Method 2 - seaborn
# your code here


age = titanic['age']
fare = titanic['fare']

fig11,ax11 = plt.subplots(figsize=(30,5))
sns.lineplot(data=titanic, x = age, y = fare);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
correlation = titanic.corr()
mask = np.triu(np.ones_like(correlation, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(correlation, mask=mask, cmap=cmap, vmax=.3, center=0,square=True,annot=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.catplot(data=titanic, x='pclass', y='age', kind = 'box')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here 
sns.catplot(data=titanic, x='sex', y='age', kind = 'box')
